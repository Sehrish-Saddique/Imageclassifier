# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import cv2
from matplotlib import pyplot as plt
import numpy as np

# Load pre-trained MobileNetV2 model
model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=True)

# Function to predict image classes from a given image path
def predict_image_from_path(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Make predictions
    predictions = model.predict(img_array)
    decoded_predictions = decode_predictions(predictions, top=3)[0]

    # Display predictions
    print("Predictions:")
    for _, label, confidence in decoded_predictions:
        print(f"{label}: {confidence * 100:.2f}%")

    # Display the image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# Example usage:
image_path = 'snail.jpg'  # Replace with the path to your test image
predict_image_from_path(image_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 4
#       2 from tensorflow.keras.preprocessing import image
#       3 from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
# ----> 4 import cv2
#       5 from matplotlib import pyplot as plt
#       6 import numpy as np
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt

# Load pre-trained MobileNetV2 model
model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=True)

# Function to predict image classes
def predict_image(image_path):
    try:
        img = image.load_img(image_path, target_size=(224, 224))  # Load image with target size
        img_array = image.img_to_array(img)  # Convert image to array
        img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions for model input
        img_array = preprocess_input(img_array)  # Preprocess the input image
        predictions = model.predict(img_array)  # Make predictions
        decoded_predictions = decode_predictions(predictions, top=3)[0]  # Decode predictions
        
        # Display image with predictions
        plt.imshow(img)
        plt.axis('off')
        plt.title('Predictions:', fontsize=14, fontweight='bold', color='white')  # Title properties
        
        # Text properties
        text_style = {'fontsize': 12, 'color': 'red', 'fontstyle': 'italic', 'weight': 'bold'}

        for i, (_, label, confidence) in enumerate(decoded_predictions):
            plt.text(0, i * 20 + 20, f"{label}: {confidence * 100:.2f}%", **text_style)
        plt.show()
    
    except Exception as e:
        print(f"Error occurred: {e}")

# Perform prediction for a single image
image_path = 'snail.jpg'  # Replace with the path to your test image
predict_image(image_path)
# Out:
# 1/1 [==============================] - 1s 509ms/step

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# 2023-12-13 15:15:46.978125: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-13 15:15:47.016903: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 15:15:47.016953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 15:15:47.018239: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 15:15:47.024214: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...
